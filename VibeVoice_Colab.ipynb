# %% [markdown]
# <a href="https://colab.research.google.com/github/saimahendra282/VibeVoiceTTS-Collab/blob/main/VibeVoice_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VibeVoice Colab
# ### 🏷️ **Credits & License**
#
# * 🔗 [VibeVoice GitHub Repository](https://github.com/microsoft/VibeVoice)
# * 🤗 [VibeVoice on Hugging Face](https://huggingface.co/microsoft/VibeVoice-1.5B)
# * 📄 **License**: Provided under the [MIT License](https://github.com/microsoft/VibeVoice/blob/main/LICENSE)
#
# ### ⚠️ **Usage Disclaimer**
#
# This tool enables **AI-generated podcast creation** using cloned voices. While it can be a powerful resource for storytelling, education, and creative projects, it also carries risks if misused. By using this tool, you agree to the following guidelines:
#
# * **No Misrepresentation**: Do not use cloned voices to impersonate real people or mislead listeners into believing AI-generated voices are authentic recordings without disclosure.
# * **Transparency**: Clearly disclose when podcast content has been generated with AI, including synthetic voices or AI-written scripts.
# * **No Harmful Content**: Do not produce or distribute content that promotes hate, harassment, misinformation, defamation, or any form of harmful/deceptive material.
# * **Legal Compliance**: Ensure all use of this tool complies with copyright laws, data protection regulations, and all applicable legal and ethical standards.
# * **Respect for Consent**: Do not replicate or publish anyone’s voice without explicit permission.
#
# > ⚖️ **Legal Responsibility**
#
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
# @title Install VibeVoice

# %cd /content/


# !git clone https://github.com/microsoft/VibeVoice.git
# Download colab.py
# %cd /content/VibeVoice/demo
# !wget https://raw.githubusercontent.com/NeuralFalconYT/VibeVoice/refs/heads/main/demo/colab.py


# (Optional) If you experience compatibility issues with the latest version, you can use a pinned fork instead:
# !git clone https://github.com/NeuralFalconYT/VibeVoice.git



# %cd /content/VibeVoice/
# !pip install -e .
# !pip install pydub>=0.25.1

from IPython.display import clear_output
clear_output()

# %%
#@title Run Official Gradio UI
# !python /content/VibeVoice/demo/gradio_demo.py --model_path "microsoft/VibeVoice-1.5B" --inference_steps 10 --share

# %%
#@title Automatically save podcast to your Google Drive [Optional]
Enable_Drive_Save= False  # @param {type: "boolean"}
if Enable_Drive_Save:
  from google.colab import drive
  drive.mount('/content/gdrive/')

# %%
#@title Run VibeVoice Podcast
# !python /content/VibeVoice/demo/colab.py --model_path microsoft/VibeVoice-1.5B --inference_steps 10 --debug --share
# Out:
# 2025-10-01 04:39:33.582005: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759293573.601444    2573 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759293573.607330    2573 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759293573.622255    2573 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759293573.622283    2573 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759293573.622287    2573 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759293573.622292    2573 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-01 04:39:33.627306: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:vibevoice.modular.modular_vibevoice_tokenizer:APEX FusedRMSNorm not available, using native implementation
# 📂 Download directory: /content/VibeVoice/VibeVoice-1.5B
# 📦 Found 9 files in repo 'microsoft/VibeVoice-1.5B'. Checking cache ...
# Processing files:   0% 0/9 [00:00<?, ?file/s]
# .gitattributes:   0% 0.00/1.57k [00:00<?, ?B/s]
# .gitattributes: 16.0kB [00:00, 125kB/s]
# ⬇️ Downloaded: .gitattributes
# Processing files:  11% 1/9 [00:00<00:02,  3.38file/s]
# README.md:   0% 0.00/7.10k [00:00<?, ?B/s]
# README.md: 16.0kB [00:00, 132kB/s]
# ⬇️ Downloaded: README.md
# Processing files:  22% 2/9 [00:00<00:01,  3.68file/s]
# config.json:   0% 0.00/2.70k [00:00<?, ?B/s]
# config.json: 16.0kB [00:00, 113kB/s]
# ⬇️ Downloaded: config.json
# Processing files:  33% 3/9 [00:00<00:01,  3.60file/s]
# Fig1.png:   0% 0.00/150k [00:00<?, ?B/s]
# Fig1.png: 160kB [00:00, 998kB/s]
# ⬇️ Downloaded: Fig1.png
# Processing files:  44% 4/9 [00:01<00:01,  2.57file/s]
# model-00001-of-00003.safetensors:   0% 0.00/1.84G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 8.00k/1.84G [00:00<8:50:18, 62.1kB/s]
# model-00001-of-00003.safetensors:   1% 13.5M/1.84G [00:00<00:26, 73.3MB/s]
# model-00001-of-00003.safetensors:   2% 36.4M/1.84G [00:00<00:13, 144MB/s]
# model-00001-of-00003.safetensors:   3% 61.6M/1.84G [00:00<00:10, 190MB/s]
# model-00001-of-00003.safetensors:   5% 87.9M/1.84G [00:00<00:08, 220MB/s]
# model-00001-of-00003.safetensors:   6% 110M/1.84G [00:00<00:08, 221MB/s]
# model-00001-of-00003.safetensors:   7% 131M/1.84G [00:00<00:08, 212MB/s]
# model-00001-of-00003.safetensors:   8% 154M/1.84G [00:00<00:08, 219MB/s]
# model-00001-of-00003.safetensors:   9% 175M/1.84G [00:00<00:08, 215MB/s]
# model-00001-of-00003.safetensors:  10% 197M/1.84G [00:01<00:08, 220MB/s]
# model-00001-of-00003.safetensors:  12% 224M/1.84G [00:01<00:07, 239MB/s]
# model-00001-of-00003.safetensors:  14% 257M/1.84G [00:01<00:06, 271MB/s]
# model-00001-of-00003.safetensors:  16% 294M/1.84G [00:01<00:05, 305MB/s]
# model-00001-of-00003.safetensors:  17% 325M/1.84G [00:01<00:05, 312MB/s]
# model-00001-of-00003.safetensors:  19% 356M/1.84G [00:01<00:05, 317MB/s]
# model-00001-of-00003.safetensors:  21% 392M/1.84G [00:01<00:04, 335MB/s]
# model-00001-of-00003.safetensors:  23% 424M/1.84G [00:01<00:04, 334MB/s]
# model-00001-of-00003.safetensors:  24% 459M/1.84G [00:01<00:04, 342MB/s]
# model-00001-of-00003.safetensors:  26% 492M/1.84G [00:03<00:30, 48.3MB/s]
# model-00001-of-00003.safetensors:  27% 515M/1.84G [00:04<00:24, 57.5MB/s]
# model-00001-of-00003.safetensors:  29% 545M/1.84G [00:04<00:18, 76.5MB/s]
# model-00001-of-00003.safetensors:  31% 578M/1.84G [00:04<00:13, 102MB/s]
# model-00001-of-00003.safetensors:  32% 608M/1.84G [00:04<00:10, 127MB/s]
# model-00001-of-00003.safetensors:  34% 635M/1.84G [00:04<00:08, 149MB/s]
# model-00001-of-00003.safetensors:  35% 665M/1.84G [00:04<00:07, 177MB/s]
# model-00001-of-00003.safetensors:  37% 697M/1.84G [00:04<00:05, 208MB/s]
# model-00001-of-00003.safetensors:  39% 726M/1.84G [00:05<00:10, 111MB/s]
# model-00001-of-00003.safetensors:  40% 758M/1.84G [00:05<00:08, 140MB/s]
# model-00001-of-00003.safetensors:  42% 782M/1.84G [00:05<00:07, 158MB/s]
# model-00001-of-00003.safetensors:  43% 810M/1.84G [00:05<00:06, 182MB/s]
# model-00001-of-00003.safetensors:  44% 835M/1.84G [00:05<00:05, 189MB/s]
# model-00001-of-00003.safetensors:  46% 863M/1.84G [00:05<00:05, 209MB/s]
# model-00001-of-00003.safetensors:  47% 888M/1.84G [00:06<00:05, 204MB/s]
# model-00001-of-00003.safetensors:  48% 910M/1.84G [00:08<00:28, 35.6MB/s]
# model-00001-of-00003.safetensors:  49% 926M/1.84G [00:08<00:23, 42.9MB/s]
# model-00001-of-00003.safetensors:  51% 952M/1.84G [00:08<00:16, 59.0MB/s]
# model-00001-of-00003.safetensors:  52% 988M/1.84G [00:08<00:10, 88.2MB/s]
# model-00001-of-00003.safetensors:  54% 0.99G/1.84G [00:08<00:07, 114MB/s]
# model-00001-of-00003.safetensors:  56% 1.02G/1.84G [00:08<00:06, 141MB/s]
# model-00001-of-00003.safetensors:  57% 1.05G/1.84G [00:08<00:04, 173MB/s]
# model-00001-of-00003.safetensors:  59% 1.08G/1.84G [00:08<00:03, 207MB/s]
# model-00001-of-00003.safetensors:  61% 1.12G/1.84G [00:08<00:03, 237MB/s]
# model-00001-of-00003.safetensors:  63% 1.15G/1.84G [00:09<00:02, 271MB/s]
# model-00001-of-00003.safetensors:  64% 1.18G/1.84G [00:09<00:02, 274MB/s]
# model-00001-of-00003.safetensors:  66% 1.21G/1.84G [00:09<00:02, 284MB/s]
# model-00001-of-00003.safetensors:  68% 1.24G/1.84G [00:09<00:02, 290MB/s]
# model-00001-of-00003.safetensors:  69% 1.27G/1.84G [00:09<00:02, 294MB/s]
# model-00001-of-00003.safetensors:  71% 1.30G/1.84G [00:09<00:01, 307MB/s]
# model-00001-of-00003.safetensors:  73% 1.33G/1.84G [00:09<00:01, 306MB/s]
# model-00001-of-00003.safetensors:  74% 1.36G/1.84G [00:09<00:01, 292MB/s]
# model-00001-of-00003.safetensors:  76% 1.39G/1.84G [00:09<00:01, 296MB/s]
# model-00001-of-00003.safetensors:  77% 1.42G/1.84G [00:10<00:01, 278MB/s]
# model-00001-of-00003.safetensors:  79% 1.45G/1.84G [00:12<00:09, 42.3MB/s]
# model-00001-of-00003.safetensors:  80% 1.47G/1.84G [00:12<00:08, 50.0MB/s]
# model-00001-of-00003.safetensors:  81% 1.49G/1.84G [00:12<00:06, 61.9MB/s]
# model-00001-of-00003.safetensors:  82% 1.51G/1.84G [00:12<00:04, 79.6MB/s]
# model-00001-of-00003.safetensors:  84% 1.54G/1.84G [00:12<00:02, 111MB/s]
# model-00001-of-00003.safetensors:  85% 1.56G/1.84G [00:12<00:02, 132MB/s]
# model-00001-of-00003.safetensors:  86% 1.59G/1.84G [00:12<00:01, 158MB/s]
# model-00001-of-00003.safetensors:  88% 1.62G/1.84G [00:12<00:01, 192MB/s]
# model-00001-of-00003.safetensors:  90% 1.65G/1.84G [00:13<00:00, 223MB/s]
# model-00001-of-00003.safetensors:  92% 1.69G/1.84G [00:13<00:00, 252MB/s]
# model-00001-of-00003.safetensors:  93% 1.72G/1.84G [00:13<00:00, 276MB/s]
# model-00001-of-00003.safetensors:  95% 1.75G/1.84G [00:13<00:00, 284MB/s]
# model-00001-of-00003.safetensors:  97% 1.78G/1.84G [00:13<00:00, 301MB/s]
# model-00001-of-00003.safetensors: 1.84GB [00:13, 145MB/s]
# ⬇️ Downloaded: model-00001-of-00003.safetensors
# Processing files:  56% 5/9 [00:15<00:20,  5.22s/file]
# model-00002-of-00003.safetensors:   0% 0.00/1.85G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 8.00k/1.85G [00:00<8:30:43, 64.7kB/s]
# model-00002-of-00003.safetensors:   1% 19.5M/1.85G [00:00<00:18, 108MB/s]
# model-00002-of-00003.safetensors:   3% 49.7M/1.85G [00:00<00:09, 198MB/s]
# model-00002-of-00003.safetensors:   4% 80.6M/1.85G [00:00<00:07, 246MB/s]
# model-00002-of-00003.safetensors:   6% 112M/1.85G [00:00<00:06, 276MB/s]
# model-00002-of-00003.safetensors:   7% 140M/1.85G [00:00<00:06, 282MB/s]
# model-00002-of-00003.safetensors:   9% 172M/1.85G [00:00<00:06, 298MB/s]
# model-00002-of-00003.safetensors:  11% 202M/1.85G [00:00<00:05, 303MB/s]
# model-00002-of-00003.safetensors:  12% 234M/1.85G [00:00<00:05, 315MB/s]
# model-00002-of-00003.safetensors:  14% 264M/1.85G [00:01<00:05, 308MB/s]
# model-00002-of-00003.safetensors:  16% 294M/1.85G [00:01<00:05, 292MB/s]
# model-00002-of-00003.safetensors:  17% 326M/1.85G [00:01<00:05, 304MB/s]
# model-00002-of-00003.safetensors:  19% 360M/1.85G [00:01<00:05, 319MB/s]
# model-00002-of-00003.safetensors:  21% 392M/1.85G [00:01<00:04, 324MB/s]
# model-00002-of-00003.safetensors:  22% 423M/1.85G [00:01<00:05, 298MB/s]
# model-00002-of-00003.safetensors:  24% 452M/1.85G [00:01<00:05, 274MB/s]
# model-00002-of-00003.safetensors:  25% 478M/1.85G [00:01<00:05, 260MB/s]
# model-00002-of-00003.safetensors:  27% 506M/1.85G [00:01<00:05, 266MB/s]
# model-00002-of-00003.safetensors:  28% 532M/1.85G [00:02<00:05, 250MB/s]
# model-00002-of-00003.safetensors:  29% 558M/1.85G [00:02<00:05, 257MB/s]
# model-00002-of-00003.safetensors:  31% 587M/1.85G [00:02<00:05, 270MB/s]
# model-00002-of-00003.safetensors:  32% 613M/1.85G [00:02<00:05, 265MB/s]
# model-00002-of-00003.safetensors:  34% 638M/1.85G [00:04<00:34, 38.1MB/s]
# model-00002-of-00003.safetensors:  35% 656M/1.85G [00:04<00:28, 45.9MB/s]
# model-00002-of-00003.safetensors:  36% 683M/1.85G [00:04<00:20, 62.4MB/s]
# model-00002-of-00003.safetensors:  38% 715M/1.85G [00:04<00:14, 87.9MB/s]
# model-00002-of-00003.safetensors:  40% 747M/1.85G [00:04<00:10, 117MB/s]
# model-00002-of-00003.safetensors:  41% 773M/1.85G [00:05<00:08, 140MB/s]
# model-00002-of-00003.safetensors:  43% 804M/1.85G [00:05<00:06, 170MB/s]
# model-00002-of-00003.safetensors:  44% 835M/1.85G [00:05<00:05, 202MB/s]
# model-00002-of-00003.safetensors:  46% 868M/1.85G [00:05<00:04, 233MB/s]
# model-00002-of-00003.safetensors:  48% 903M/1.85G [00:05<00:03, 265MB/s]
# model-00002-of-00003.safetensors:  49% 935M/1.85G [00:05<00:03, 282MB/s]
# model-00002-of-00003.safetensors:  51% 967M/1.85G [00:05<00:03, 293MB/s]
# model-00002-of-00003.safetensors:  53% 998M/1.85G [00:05<00:03, 280MB/s]
# model-00002-of-00003.safetensors:  54% 1.00G/1.85G [00:05<00:03, 289MB/s]
# model-00002-of-00003.safetensors:  56% 1.03G/1.85G [00:06<00:02, 298MB/s]
# model-00002-of-00003.safetensors:  58% 1.06G/1.85G [00:06<00:02, 301MB/s]
# model-00002-of-00003.safetensors:  59% 1.09G/1.85G [00:06<00:02, 296MB/s]
# model-00002-of-00003.safetensors:  61% 1.12G/1.85G [00:06<00:02, 287MB/s]
# model-00002-of-00003.safetensors:  62% 1.15G/1.85G [00:06<00:02, 295MB/s]
# model-00002-of-00003.safetensors:  64% 1.18G/1.85G [00:07<00:12, 57.6MB/s]
# model-00002-of-00003.safetensors:  65% 1.20G/1.85G [00:08<00:14, 47.0MB/s]
# model-00002-of-00003.safetensors:  66% 1.22G/1.85G [00:08<00:11, 59.5MB/s]
# model-00002-of-00003.safetensors:  67% 1.24G/1.85G [00:08<00:08, 74.0MB/s]
# model-00002-of-00003.safetensors:  68% 1.26G/1.85G [00:09<00:06, 92.8MB/s]
# model-00002-of-00003.safetensors:  70% 1.29G/1.85G [00:09<00:05, 119MB/s]
# model-00002-of-00003.safetensors:  71% 1.31G/1.85G [00:09<00:04, 135MB/s]
# model-00002-of-00003.safetensors:  72% 1.33G/1.85G [00:09<00:03, 144MB/s]
# model-00002-of-00003.safetensors:  73% 1.35G/1.85G [00:09<00:03, 164MB/s]
# model-00002-of-00003.safetensors:  75% 1.38G/1.85G [00:09<00:02, 186MB/s]
# model-00002-of-00003.safetensors:  76% 1.40G/1.85G [00:09<00:02, 199MB/s]
# model-00002-of-00003.safetensors:  77% 1.43G/1.85G [00:09<00:02, 218MB/s]
# model-00002-of-00003.safetensors:  78% 1.45G/1.85G [00:09<00:01, 220MB/s]
# model-00002-of-00003.safetensors:  80% 1.47G/1.85G [00:09<00:01, 228MB/s]
# model-00002-of-00003.safetensors:  81% 1.49G/1.85G [00:10<00:01, 229MB/s]
# model-00002-of-00003.safetensors:  82% 1.52G/1.85G [00:10<00:01, 232MB/s]
# model-00002-of-00003.safetensors:  83% 1.54G/1.85G [00:10<00:02, 149MB/s]
# model-00002-of-00003.safetensors:  85% 1.56G/1.85G [00:10<00:01, 169MB/s]
# model-00002-of-00003.safetensors:  86% 1.59G/1.85G [00:10<00:01, 194MB/s]
# model-00002-of-00003.safetensors:  87% 1.61G/1.85G [00:10<00:01, 213MB/s]
# model-00002-of-00003.safetensors:  89% 1.64G/1.85G [00:10<00:00, 225MB/s]
# model-00002-of-00003.safetensors:  90% 1.66G/1.85G [00:12<00:03, 52.6MB/s]
# model-00002-of-00003.safetensors:  92% 1.69G/1.85G [00:12<00:02, 75.9MB/s]
# model-00002-of-00003.safetensors:  94% 1.73G/1.85G [00:12<00:01, 113MB/s]
# model-00002-of-00003.safetensors:  96% 1.77G/1.85G [00:12<00:00, 143MB/s]
# model-00002-of-00003.safetensors:  97% 1.79G/1.85G [00:12<00:00, 164MB/s]
# model-00002-of-00003.safetensors: 1.85GB [00:12, 154MB/s]
# ⬇️ Downloaded: model-00002-of-00003.safetensors
# Processing files:  67% 6/9 [00:28<00:23,  7.87s/file]
# model-00003-of-00003.safetensors:   0% 0.00/1.35G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0% 8.00k/1.35G [00:00<7:01:38, 57.3kB/s]
# model-00003-of-00003.safetensors:   1% 16.6M/1.35G [00:00<00:16, 87.0MB/s]
# model-00003-of-00003.safetensors:   4% 49.5M/1.35G [00:00<00:07, 194MB/s]
# model-00003-of-00003.safetensors:   6% 81.4M/1.35G [00:00<00:05, 247MB/s]
# model-00003-of-00003.safetensors:   8% 112M/1.35G [00:00<00:04, 271MB/s]
# model-00003-of-00003.safetensors:  10% 143M/1.35G [00:00<00:04, 290MB/s]
# model-00003-of-00003.safetensors:  13% 175M/1.35G [00:00<00:04, 305MB/s]
# model-00003-of-00003.safetensors:  15% 205M/1.35G [00:00<00:04, 308MB/s]
# model-00003-of-00003.safetensors:  17% 236M/1.35G [00:00<00:03, 313MB/s]
# model-00003-of-00003.safetensors:  19% 267M/1.35G [00:01<00:03, 318MB/s]
# model-00003-of-00003.safetensors:  22% 298M/1.35G [00:01<00:04, 283MB/s]
# model-00003-of-00003.safetensors:  24% 327M/1.35G [00:01<00:03, 289MB/s]
# model-00003-of-00003.safetensors:  26% 357M/1.35G [00:01<00:03, 298MB/s]
# model-00003-of-00003.safetensors:  28% 388M/1.35G [00:01<00:03, 305MB/s]
# model-00003-of-00003.safetensors:  30% 419M/1.35G [00:01<00:03, 310MB/s]
# model-00003-of-00003.safetensors:  33% 451M/1.35G [00:01<00:03, 318MB/s]
# model-00003-of-00003.safetensors:  35% 484M/1.35G [00:01<00:02, 327MB/s]
# model-00003-of-00003.safetensors:  37% 515M/1.35G [00:01<00:02, 318MB/s]
# model-00003-of-00003.safetensors:  40% 547M/1.35G [00:01<00:02, 323MB/s]
# model-00003-of-00003.safetensors:  42% 580M/1.35G [00:02<00:02, 330MB/s]
# model-00003-of-00003.safetensors:  44% 612M/1.35G [00:02<00:02, 316MB/s]
# model-00003-of-00003.safetensors:  46% 642M/1.35G [00:02<00:02, 309MB/s]
# model-00003-of-00003.safetensors:  49% 672M/1.35G [00:02<00:02, 308MB/s]
# model-00003-of-00003.safetensors:  51% 701M/1.35G [00:02<00:02, 296MB/s]
# model-00003-of-00003.safetensors:  53% 730M/1.35G [00:02<00:02, 279MB/s]
# model-00003-of-00003.safetensors:  55% 756M/1.35G [00:02<00:02, 276MB/s]
# model-00003-of-00003.safetensors:  57% 783M/1.35G [00:02<00:02, 257MB/s]
# model-00003-of-00003.safetensors:  58% 808M/1.35G [00:02<00:02, 254MB/s]
# model-00003-of-00003.safetensors:  60% 832M/1.35G [00:03<00:02, 239MB/s]
# model-00003-of-00003.safetensors:  62% 858M/1.35G [00:03<00:02, 249MB/s]
# model-00003-of-00003.safetensors:  64% 885M/1.35G [00:03<00:02, 258MB/s]
# model-00003-of-00003.safetensors:  66% 910M/1.35G [00:03<00:02, 236MB/s]
# model-00003-of-00003.safetensors:  68% 936M/1.35G [00:03<00:01, 246MB/s]
# model-00003-of-00003.safetensors:  69% 960M/1.35G [00:04<00:05, 76.5MB/s]
# model-00003-of-00003.safetensors:  72% 995M/1.35G [00:04<00:03, 109MB/s]
# model-00003-of-00003.safetensors:  74% 1.00G/1.35G [00:04<00:02, 139MB/s]
# model-00003-of-00003.safetensors:  77% 1.03G/1.35G [00:04<00:02, 169MB/s]
# model-00003-of-00003.safetensors:  79% 1.06G/1.35G [00:04<00:01, 195MB/s]
# model-00003-of-00003.safetensors:  81% 1.09G/1.35G [00:04<00:01, 223MB/s]
# model-00003-of-00003.safetensors:  83% 1.12G/1.35G [00:05<00:00, 252MB/s]
# model-00003-of-00003.safetensors:  86% 1.16G/1.35G [00:05<00:00, 273MB/s]
# model-00003-of-00003.safetensors:  88% 1.19G/1.35G [00:05<00:00, 293MB/s]
# model-00003-of-00003.safetensors:  90% 1.22G/1.35G [00:05<00:00, 284MB/s]
# model-00003-of-00003.safetensors:  93% 1.25G/1.35G [00:05<00:00, 295MB/s]
# model-00003-of-00003.safetensors:  95% 1.28G/1.35G [00:05<00:00, 305MB/s]
# model-00003-of-00003.safetensors:  97% 1.31G/1.35G [00:05<00:00, 315MB/s]
# model-00003-of-00003.safetensors: 1.35GB [00:05, 250MB/s]
# ⬇️ Downloaded: model-00003-of-00003.safetensors
# Processing files:  78% 7/9 [00:34<00:14,  7.24s/file]
# model.safetensors.index.json:   0% 0.00/120k [00:00<?, ?B/s]
# model.safetensors.index.json: 128kB [00:00, 890kB/s]
# ⬇️ Downloaded: model.safetensors.index.json
# Processing files:  89% 8/9 [00:34<00:05,  5.04s/file]
# preprocessor_config.json:   0% 0.00/351 [00:00<?, ?B/s]
# preprocessor_config.json: 16.0kB [00:00, 127kB/s]
# ⬇️ Downloaded: preprocessor_config.json
# Processing files: 100% 9/9 [00:34<00:00,  3.86s/file]
# 🎙️ Initializing VibeVoice ...
# Loading processor & model from /content/VibeVoice/VibeVoice-1.5B
# tokenizer_config.json: 7.23kB [00:00, 31.1MB/s]
# vocab.json: 2.78MB [00:00, 69.8MB/s]
# merges.txt: 1.67MB [00:00, 139MB/s]
# tokenizer.json: 7.03MB [00:00, 182MB/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Qwen2Tokenizer'.
# The class this function is called from is 'VibeVoiceTextTokenizerFast'.
# Loading checkpoint shards: 100% 3/3 [00:22<00:00,  7.54s/it]
# Language model attention: sdpa
# Found 9 voice files in /content/VibeVoice/demo/voices
# 🚀 Launching Gradio Demo...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://af59d8c008acfe0475.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Generating (active: 1/1):  12% 67/570 [00:15<02:11,  3.82it/s]🛑 Audio generation stop requested
# Generating (active: 1/1):  16% 89/570 [00:20<01:43,  4.63it/s]🛑 Audio generation stop requested
# Generating (active: 1/1):  17% 98/570 [00:22<01:40,  4.71it/s]🛑 Audio generation stop requested
#
# 🚫 Generation interrupted by user. Finalizing partial files...
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Partial generation successful!
# 🎵 Audio: ./podcast_audio/hello_and_welcome_to_planet_in_16e7a4.wav
# 📄 Timestamps: ./podcast_audio/hello_and_welcome_to_planet_in_16e7a4.json
#
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://af59d8c008acfe0475.gradio.live
